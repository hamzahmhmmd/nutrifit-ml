# %% [markdown]
# # Mengukur model YOLOv5 (PyTorch based) dengan data TEST dari dataset FOOD15 versi 1

# %%
! git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5
! pip install -r requirements.txt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! cp /content/drive/MyDrive/roboflow-food15-yoloV5-pyTorch.zip /content

# %%
# %cd /content
! unzip /content/roboflow-food15-yoloV5-pyTorch.zip

# %%
! mkdir /content/models

# %%
! mkdir /content/models/YOLOv5s
! mkdir /content/models/YOLOv5s6
! mkdir /content/models/YOLOv5s6-transformer
! mkdir /content/models/YOLOv5m
! mkdir /content/models/YOLOv5m6

# %%
! cp /content/drive/MyDrive/YOLOv5s-retrain_weight_food15/runs/train/yolov5m_results2/weights/* \
  /content/models/YOLOv5m

# %%
# %cd /content/yolov5
# !python test.py \
  --weights ../models/YOLOv5m/best.pt \
  --data ../data.yaml \
  --img 640 \
  --iou 0.45 \
  --conf 0.25 \
  --name YOLOv5m-best \
  --verbose --save-txt
# Out:
# /content/yolov5
# Namespace(augment=False, batch_size=32, conf_thres=0.25, data='../data.yaml', device='', exist_ok=False, img_size=640, iou_thres=0.45, name='YOLOv5m-best', project='runs/test', save_conf=False, save_hybrid=False, save_json=False, save_txt=True, single_cls=False, task='val', verbose=True, weights=['../models/YOLOv5m/best.pt'])
# YOLOv5 🚀 v5.0-115-g407dc50 torch 1.8.1+cu101 CPU
#
# Fusing layers...
# Model Summary: 308 layers, 21094212 parameters, 0 gradients, 50.5 GFLOPS
# val: Scanning '../valid/labels.cache' images and labels... 96 found, 0 missing, 0 empty, 0 corrupted: 100% 96/96 [00:00<00:00, 716464.74it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 3/3 [02:02<00:00, 40.99s/it]
#                  all          96         169       0.711       0.536       0.498       0.304
#           beef curry          96          12       0.875       0.583       0.577       0.433
# ...

# %%
# %cd /content/yolov5
# !python test.py \
  --weights ../models/YOLOv5m/last.pt \
  --data ../data.yaml \
  --img 640 \
  --iou 0.45 \
  --conf 0.25 \
  --name YOLOv5m-last \
  --verbose --save-txt
# Out:
# /content/yolov5
# Namespace(augment=False, batch_size=32, conf_thres=0.25, data='../data.yaml', device='', exist_ok=False, img_size=640, iou_thres=0.45, name='YOLOv5m-last', project='runs/test', save_conf=False, save_hybrid=False, save_json=False, save_txt=True, single_cls=False, task='val', verbose=True, weights=['../models/YOLOv5m/last.pt'])
# YOLOv5 🚀 v5.0-115-g407dc50 torch 1.8.1+cu101 CPU
#
# Fusing layers...
# Model Summary: 308 layers, 21094212 parameters, 0 gradients, 50.5 GFLOPS
# val: Scanning '../valid/labels.cache' images and labels... 96 found, 0 missing, 0 empty, 0 corrupted: 100% 96/96 [00:00<00:00, 567917.04it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 3/3 [01:57<00:00, 39.17s/it]
#                  all          96         169       0.665       0.567       0.534        0.32
#           beef curry          96          12           1       0.833       0.838       0.559
# ...

# %%
! cp /content/drive/MyDrive/YOLOv5m6_weight_food15/runs/train/yolov5m6_results/weights/* \
  /content/models/YOLOv5m6

# %%
# %cd /content/yolov5
# !python test.py \
  --weights ../models/YOLOv5m6/best.pt \
  --data ../data.yaml \
  --img 640 \
  --iou 0.45 \
  --conf 0.25 \
  --name YOLOv5m6-best \
  --verbose --save-txt
# Out:
# /content/yolov5
# Namespace(augment=False, batch_size=32, conf_thres=0.25, data='../data.yaml', device='', exist_ok=False, img_size=640, iou_thres=0.45, name='YOLOv5m6-best', project='runs/test', save_conf=False, save_hybrid=False, save_json=False, save_txt=True, single_cls=False, task='val', verbose=True, weights=['../models/YOLOv5m6/best.pt'])
# YOLOv5 🚀 v5.0-115-g407dc50 torch 1.8.1+cu101 CPU
#
# Fusing layers...
# Model Summary: 396 layers, 35514432 parameters, 0 gradients, 51.5 GFLOPS
# val: Scanning '../valid/labels.cache' images and labels... 96 found, 0 missing, 0 empty, 0 corrupted: 100% 96/96 [00:00<00:00, 676728.04it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 3/3 [02:05<00:00, 41.98s/it]
#                  all          96         169       0.622       0.745       0.622       0.288
#           beef curry          96          12       0.733       0.917       0.899       0.514
# ...

# %%
# %cd /content/yolov5
# !python test.py \
  --weights ../models/YOLOv5m6/last.pt \
  --data ../data.yaml \
  --img 640 \
  --iou 0.45 \
  --conf 0.25 \
  --name YOLOv5m6-last \
  --verbose --save-txt
# Out:
# /content/yolov5
# Namespace(augment=False, batch_size=32, conf_thres=0.25, data='../data.yaml', device='', exist_ok=False, img_size=640, iou_thres=0.45, name='YOLOv5m6-last', project='runs/test', save_conf=False, save_hybrid=False, save_json=False, save_txt=True, single_cls=False, task='val', verbose=True, weights=['../models/YOLOv5m6/last.pt'])
# YOLOv5 🚀 v5.0-115-g407dc50 torch 1.8.1+cu101 CPU
#
# Fusing layers...
# Model Summary: 396 layers, 35514432 parameters, 0 gradients, 51.5 GFLOPS
# val: Scanning '../valid/labels.cache' images and labels... 96 found, 0 missing, 0 empty, 0 corrupted: 100% 96/96 [00:00<00:00, 694229.63it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 3/3 [02:07<00:00, 42.37s/it]
#                  all          96         169        0.59       0.755       0.621       0.305
#           beef curry          96          12       0.706           1       0.963       0.562
# ...

# %%
! cp /content/drive/MyDrive/YOLOv5s_weight_food15/runs/train/yolov5s_results/weights/last-bener.pt \
  /content/models/YOLOv5s

! cp /content/drive/MyDrive/YOLOv5s_weight_food15/runs/train/yolov5s_results/weights/best.pt \
  /content/models/YOLOv5s

# %%
# %cd /content/yolov5
# !python /content/yolov5/test.py \
  --weights ../models/YOLOv5s/best.pt \
  --data ../data.yaml \
  --img 640 \
  --iou 0.45 \
  --conf 0.25 \
  --name YOLOv5s-best \
  --verbose --save-txt
# Out:
# Namespace(augment=False, batch_size=32, conf_thres=0.25, data='../data.yaml', device='', exist_ok=False, img_size=640, iou_thres=0.45, name='YOLOv5s-best', project='runs/test', save_conf=False, save_hybrid=False, save_json=False, save_txt=True, single_cls=False, task='val', verbose=True, weights=['../models/YOLOv5s/best.pt'])
# YOLOv5 🚀 v5.0-115-g407dc50 torch 1.8.1+cu101 CPU
#
# Fusing layers...
# Model Summary: 232 layers, 7284276 parameters, 0 gradients
# val: Scanning '../valid/labels.cache' images and labels... 96 found, 0 missing, 0 empty, 0 corrupted: 100% 96/96 [00:00<00:00, 719023.54it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 3/3 [00:52<00:00, 17.52s/it]
#                  all          96         169       0.466       0.528        0.46        0.23
#           beef curry          96          12       0.917       0.918       0.968       0.467
# ...

# %%
# %cd /content/yolov5
# !python /content/yolov5/test.py \
  --weights /content/drive/MyDrive/YOLOv5s-retrain_weight_food15/runs/train/yolov5s_results/weights/best.pt \
  --data ../data.yaml \
  --img 640 \
  --iou 0.45 \
  --conf 0.25 \
  --name YOLOv5s-best \
  --verbose --save-txt
# Out:
# /content/yolov5
# Namespace(augment=False, batch_size=32, conf_thres=0.25, data='../data.yaml', device='', exist_ok=False, img_size=640, iou_thres=0.45, name='YOLOv5s-best', project='runs/test', save_conf=False, save_hybrid=False, save_json=False, save_txt=True, single_cls=False, task='val', verbose=True, weights=['/content/drive/MyDrive/YOLOv5s-retrain_weight_food15/runs/train/yolov5s_results/weights/best.pt'])
# YOLOv5 🚀 v5.0-115-g407dc50 torch 1.8.1+cu101 CPU
#
# Fusing layers...
# Model Summary: 224 layers, 7091668 parameters, 0 gradients, 16.4 GFLOPS
# val: Scanning '../valid/labels.cache' images and labels... 96 found, 0 missing, 0 empty, 0 corrupted: 100% 96/96 [00:00<00:00, 662258.53it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 3/3 [00:58<00:00, 19.53s/it]
#                  all          96           0           0           0           0           0
# ...

# %%
# %cd /content/yolov5
# !python /content/yolov5/test.py \
  --weights ../models/YOLOv5s/last-bener.pt \
  --data ../data.yaml \
  --img 640 \
  --iou 0.45 \
  --conf 0.25 \
  --name YOLOv5s-last \
  --verbose --save-txt
# Out:
# Namespace(augment=False, batch_size=32, conf_thres=0.25, data='../data.yaml', device='', exist_ok=False, img_size=640, iou_thres=0.45, name='YOLOv5s-last', project='runs/test', save_conf=False, save_hybrid=False, save_json=False, save_txt=True, single_cls=False, task='val', verbose=True, weights=['../models/YOLOv5s/last-bener.pt'])
# YOLOv5 🚀 v5.0-115-g407dc50 torch 1.8.1+cu101 CPU
#
# Fusing layers...
# Model Summary: 232 layers, 7284276 parameters, 0 gradients
# val: Scanning '../valid/labels.cache' images and labels... 96 found, 0 missing, 0 empty, 0 corrupted: 100% 96/96 [00:00<00:00, 697839.14it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 3/3 [01:00<00:00, 20.09s/it]
#                  all          96         169       0.641       0.417        0.44       0.228
#           beef curry          96          12         0.8       0.666       0.639       0.371
# ...

# %%
! cp /content/drive/MyDrive/YOLOv5s6-transformer_weight_food15/runs/train/yolov5s-transformer_results/weights/* \
  /content/models/YOLOv5s6-transformer

# %%
# %cd /content/yolov5
# !python /content/yolov5/test.py \
  --weights ../models/YOLOv5s6-transformer/best.pt \
  --data ../data.yaml \
  --img 640 \
  --iou 0.45 \
  --conf 0.25 \
  --name YOLOv5s6-transformer-best \
  --verbose --save-txt
# Out:
# Namespace(augment=False, batch_size=32, conf_thres=0.25, data='../data.yaml', device='', exist_ok=False, img_size=640, iou_thres=0.45, name='YOLOv5s6-transformer-best', project='runs/test', save_conf=False, save_hybrid=False, save_json=False, save_txt=True, single_cls=False, task='val', verbose=True, weights=['../models/YOLOv5s6-transformer/best.pt'])
# YOLOv5 🚀 v5.0-115-g407dc50 torch 1.8.1+cu101 CPU
#
# Fusing layers...
# Model Summary: 227 layers, 7092436 parameters, 0 gradients, 16.2 GFLOPS
# val: Scanning '../valid/labels.cache' images and labels... 96 found, 0 missing, 0 empty, 0 corrupted: 100% 96/96 [00:00<00:00, 737460.04it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 3/3 [00:51<00:00, 17.19s/it]
#                  all          96         169       0.553       0.529       0.488       0.235
#           beef curry          96          12       0.846       0.917       0.861       0.392
# ...

# %%
# %cd /content/yolov5
# !python /content/yolov5/test.py \
  --weights ../models/YOLOv5s6-transformer/last.pt \
  --data ../data.yaml \
  --img 640 \
  --iou 0.45 \
  --conf 0.25 \
  --name YOLOv5s6-transformer-last \
  --verbose --save-txt
# Out:
# Namespace(augment=False, batch_size=32, conf_thres=0.25, data='../data.yaml', device='', exist_ok=False, img_size=640, iou_thres=0.45, name='YOLOv5s6-transformer-last', project='runs/test', save_conf=False, save_hybrid=False, save_json=False, save_txt=True, single_cls=False, task='val', verbose=True, weights=['../models/YOLOv5s6-transformer/last.pt'])
# YOLOv5 🚀 v5.0-115-g407dc50 torch 1.8.1+cu101 CPU
#
# Fusing layers...
# Model Summary: 227 layers, 7092436 parameters, 0 gradients, 16.2 GFLOPS
# val: Scanning '../valid/labels.cache' images and labels... 96 found, 0 missing, 0 empty, 0 corrupted: 100% 96/96 [00:00<00:00, 599186.29it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 3/3 [00:51<00:00, 17.28s/it]
#                  all          96         169       0.578       0.565       0.495       0.244
#           beef curry          96          12       0.805       0.917       0.878       0.432
# ...

# %%
! cp /content/drive/MyDrive/YOLOv5s6_weight_food15/runs/train/yolov5s6_results/weights/* \
  /content/models/YOLOv5s6

# %%
# %cd /content/yolov5
# !python /content/yolov5/test.py \
  --weights ../models/YOLOv5s6/best.pt \
  --data ../data.yaml \
  --img 640 \
  --iou 0.45 \
  --conf 0.25 \
  --name YOLOv5s6-best \
  --verbose --save-txt
# Out:
# Namespace(augment=False, batch_size=32, conf_thres=0.25, data='../data.yaml', device='', exist_ok=False, img_size=640, iou_thres=0.45, name='YOLOv5s6-best', project='runs/test', save_conf=False, save_hybrid=False, save_json=False, save_txt=True, single_cls=False, task='val', verbose=True, weights=['../models/YOLOv5s6/best.pt'])
# YOLOv5 🚀 v5.0-115-g407dc50 torch 1.8.1+cu101 CPU
#
# Fusing layers...
# Model Summary: 291 layers, 12403216 parameters, 0 gradients, 16.8 GFLOPS
# val: Scanning '../valid/labels.cache' images and labels... 96 found, 0 missing, 0 empty, 0 corrupted: 100% 96/96 [00:00<00:00, 902809.83it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 3/3 [00:54<00:00, 18.12s/it]
#                  all          96         169       0.701       0.701       0.672       0.378
#           beef curry          96          12       0.799       0.917       0.905        0.57
# ...

# %%
# %cd /content/yolov5
# !python /content/yolov5/test.py \
  --weights ../models/YOLOv5s6/last.pt \
  --data ../data.yaml \
  --img 640 \
  --iou 0.45 \
  --conf 0.25 \
  --name YOLOv5s6-last \
  --verbose --save-txt
# Out:
# Namespace(augment=False, batch_size=32, conf_thres=0.25, data='../data.yaml', device='', exist_ok=False, img_size=640, iou_thres=0.45, name='YOLOv5s6-last', project='runs/test', save_conf=False, save_hybrid=False, save_json=False, save_txt=True, single_cls=False, task='val', verbose=True, weights=['../models/YOLOv5s6/last.pt'])
# YOLOv5 🚀 v5.0-115-g407dc50 torch 1.8.1+cu101 CPU
#
# Fusing layers...
# Model Summary: 291 layers, 12403216 parameters, 0 gradients, 16.8 GFLOPS
# val: Scanning '../valid/labels.cache' images and labels... 96 found, 0 missing, 0 empty, 0 corrupted: 100% 96/96 [00:00<00:00, 858535.57it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 3/3 [00:54<00:00, 18.06s/it]
#                  all          96         169       0.722       0.614       0.601       0.353
#           beef curry          96          12       0.748           1       0.998       0.563
# ...

# %%
! cp -r /content/drive/MyDrive/YOLOv5s-retrain_weight_food15/runs/train/yolov5m_results2/weights-ema/* \
  /content/models/YOLOv5m-ema/

# %%
# %cd /content/yolov5
# !python /content/yolov5/test.py \
  --weights ../models/YOLOv5m-ema/best.pt \
  --data ../data.yaml \
  --name YOLOv5m-ema-best \
  --verbose --save-txt
# Out:
# /content/yolov5
# Namespace(augment=False, batch_size=32, conf_thres=0.001, data='../data.yaml', device='', exist_ok=False, img_size=640, iou_thres=0.6, name='YOLOv5m-ema-best', project='runs/test', save_conf=False, save_hybrid=False, save_json=False, save_txt=True, single_cls=False, task='val', verbose=True, weights=['../models/YOLOv5m-ema/best.pt'])
# YOLOv5 🚀 v5.0-115-g407dc50 torch 1.8.1+cu101 CPU
#
# Fusing layers...
# Model Summary: 308 layers, 21094212 parameters, 0 gradients, 50.5 GFLOPS
# val: Scanning '../valid/labels.cache' images and labels... 96 found, 0 missing, 0 empty, 0 corrupted: 100% 96/96 [00:00<00:00, 708896.45it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 3/3 [02:03<00:00, 41.32s/it]
#                  all          96         169       0.507       0.635       0.571       0.289
#           beef curry          96          12       0.682       0.917       0.885       0.534
# ...

# %%
# %cd /content/yolov5
# !python /content/yolov5/test.py \
  --weights ../models/YOLOv5m-ema/last.pt \
  --data ../data.yaml \
  --name YOLOv5m-ema-last \
  --verbose --save-txt
# Out:
# /content/yolov5
# Namespace(augment=False, batch_size=32, conf_thres=0.001, data='../data.yaml', device='', exist_ok=False, img_size=640, iou_thres=0.6, name='YOLOv5m-ema-last', project='runs/test', save_conf=False, save_hybrid=False, save_json=False, save_txt=True, single_cls=False, task='val', verbose=True, weights=['../models/YOLOv5m-ema/last.pt'])
# YOLOv5 🚀 v5.0-115-g407dc50 torch 1.8.1+cu101 CPU
#
# Fusing layers...
# Model Summary: 308 layers, 21094212 parameters, 0 gradients, 50.5 GFLOPS
# val: Scanning '../valid/labels.cache' images and labels... 96 found, 0 missing, 0 empty, 0 corrupted: 100% 96/96 [00:00<00:00, 711401.39it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 3/3 [01:59<00:00, 39.95s/it]
#                  all          96         169        0.51       0.619       0.582       0.295
#           beef curry          96          12       0.494           1       0.818       0.452
# ...

# %%
! cp -r /content/models/* /content/drive/MyDrive/YOLOv5-FINAL-EVALUATION/models/
